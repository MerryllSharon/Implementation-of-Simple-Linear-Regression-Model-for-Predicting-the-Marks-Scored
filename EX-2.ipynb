# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
#import libraries to find mae, mse

#read csv file
df = pd.read_csv("student_scores.csv")

#displaying the content in datafile
print(df.tail())
print(df.head())
df.info()
# Out:
#     Hours  Scores
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 532.0 bytes

# %%
# Segregating data to variables
x = df.iloc[:, :-1].values  # Hours
y = df.iloc[:,:-1].values   # Scores

# %%
#splitting train and test data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)

print("X_Training:", x_train)
print("X_Test:", x_test)
print("Y_Training:", y_train)
print("Y_Test:", y_test)
# Out:
# X_Training: [[1.1]
#  [5.1]
#  [7.7]
#  [3.3]
#  [8.3]
#  [9.2]
#  [6.1]
#  [3.5]
#  [2.7]
#  [5.5]
#  [2.7]
#  [8.5]
#  [2.5]
#  [4.8]
#  [8.9]
#  [4.5]]
# X_Test: [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]
#  [3.8]
#  [1.9]
#  [7.8]
#  [6.9]]
# Y_Training: [[1.1]
#  [5.1]
#  [7.7]
#  [3.3]
#  [8.3]
#  [9.2]
#  [6.1]
#  [3.5]
#  [2.7]
#  [5.5]
#  [2.7]
#  [8.5]
#  [2.5]
#  [4.8]
#  [8.9]
#  [4.5]]
# Y_Test: [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]
#  [3.8]
#  [1.9]
#  [7.8]
#  [6.9]]

# %%
#import linear regression model and fit the model with the data
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#displaying predicted values
Y_pred = reg.predict(x_test)

print("Predicted Scores:", Y_pred)
print("Actual Scores:", y_test)
# Out:
# Predicted Scores: [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]
#  [3.8]
#  [1.9]
#  [7.8]
#  [6.9]]
# Actual Scores: [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]
#  [3.8]
#  [1.9]
#  [7.8]
#  [6.9]]

# %%
#displaying actual values
a = Y_pred - y_test
print("Difference (Predicted - Actual):", a)
# Out:
# Difference (Predicted - Actual): [[ 1.33226763e-15]
#  [ 8.88178420e-16]
#  [-8.88178420e-16]
#  [ 8.88178420e-16]
#  [ 0.00000000e+00]
#  [ 4.44089210e-16]
#  [ 1.11022302e-15]
#  [-8.88178420e-16]
#  [-8.88178420e-16]]

# %%
#graph plot for training data
plt.scatter(x_train, y_train, color="green")
plt.plot(x_train, reg.predict(x_train), color="red")
plt.title('Training set (Hours vs Scores)')
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.show()

# %%
#graph plot for test data
plt.scatter(x_test, y_test, color="blue")
plt.plot(x_test, reg.predict(x_test), color="green")
plt.title('Testing set (Hours vs Scores)')
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.show()

# %%
#find mae,mse,rmse
mae = mean_absolute_error(y_test, Y_pred)
mse = mean_squared_error(y_test, Y_pred)
rmse = np.sqrt(mse)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Mean Absolute Error: 8.141635513917814e-16
# Mean Squared Error: 7.943391059517133e-31
# Root Mean Squared Error: 8.91257036971778e-16
